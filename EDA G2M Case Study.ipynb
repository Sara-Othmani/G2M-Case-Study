# %%
#import libraries

import os
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#define working directory 

os.chdir('C:/Users/Administrateur/Desktop/Data Glacier')
cwd = os.getcwd()

#import dataset

cab = pd.read_csv('Cab_Data.csv')
city = pd.read_csv('City.csv')
customer= pd.read_csv('Customer_ID.csv')
transaction = pd.read_csv('Transaction_ID.csv')

# %%
#Cab dataset

#show first 5 rows
cab.head()

# Info about the data
cab.info()

# Statistical data analysis
# Summary statistics
cab.describe()
# Shape of the data
cab.shape

## The cab dataset contains 359392 rows/individuals and 7 columns/variables
## The existant attribute types in this dataset are : float, int and object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  int64
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 19.2+ MB
# (359392, 7)

# %%
#cab data cleaning and preprocessing

cab.isnull().sum()
## There is no missing values
## There is no unimportant variables. No variables to drop.

#drop if there are any duplicate rows
cab = cab.drop_duplicates(keep='first')
cab
## There is no duplicate rows.
## Conclusion : Our cab data is clean.
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10000012           42375    Pink Cab     ATLANTA GA
# 2             10000013           42371    Pink Cab     ATLANTA GA
# 3             10000014           42376    Pink Cab     ATLANTA GA
# 4             10000015           42372    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95      313.6350
# 1              28.62         358.52      334.8540
# ...

# %%
#customer dataset

customer.head()
customer.info()
customer.shape

# Statistical data analysis
# Summary statistics
customer.describe()

## 49171 individuals and 4 variables.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
#         Customer ID           Age  Income (USD/Month)
# count  49171.000000  49171.000000        49171.000000
# mean   28398.252283     35.363121        15015.631856
# std    17714.137333     12.599066         8002.208253
# min        1.000000     18.000000         2000.000000
# 25%    12654.500000     25.000000         8289.500000
# 50%    27631.000000     33.000000        14656.000000
# 75%    43284.500000     42.000000        21035.000000
# max    60000.000000     65.000000        35000.000000

# %%
#customer data cleaning and preprocessing

customer.isnull().sum()
## There is no missing values
## There is no unimportant variables. No variables to drop.

#drop if there are any duplicate rows
customer = customer.drop_duplicates(keep='first')
customer
## There is no duplicate rows.
## Conclusion : Our customer data is clean.
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)
# 0            29290    Male   28               10813
# 1            27703    Male   27                9237
# 2            28712    Male   53               11242
# 3            28020    Male   23               23327
# 4            27182    Male   33                8536
# ...            ...     ...  ...                 ...
# 49166        12490    Male   33               18713
# 49167        14971    Male   30               15346
# 49168        41414    Male   38                3960
# 49169        41677    Male   23               19454
# 49170        39761  Female   32               10128
#
# [49171 rows x 4 columns]

# %%
#transaction dataset

transaction.head()
transaction.info()
transaction.shape

# Statistical data analysis
# Summary statistics
transaction.describe()

## 440098 individuals and 3 variables.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  440098 non-null  int64
#  1   Customer ID     440098 non-null  int64
#  2   Payment_Mode    440098 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB
#        Transaction ID    Customer ID
# count    4.400980e+05  440098.000000
# mean     1.022006e+07   23619.513120
# std      1.270455e+05   21195.549816
# min      1.000001e+07       1.000000
# 25%      1.011004e+07    3530.000000
# 50%      1.022006e+07   15168.000000
# 75%      1.033008e+07   43884.000000
# max      1.044011e+07   60000.000000

# %%
#transaction data cleaning and preprocessing

transaction.isnull().sum()
## There is no missing values
## There is no unimportant variables. No variables to drop.

#drop if there are any duplicate rows
transaction = transaction.drop_duplicates(keep='first')
transaction
## There is no duplicate rows.
## Conclusion : Our transaction data is clean.
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 0             10000011        29290         Card
# 1             10000012        27703         Card
# 2             10000013        28712         Cash
# 3             10000014        28020         Cash
# 4             10000015        27182         Card
# ...                ...          ...          ...
# 440093        10440104        53286         Cash
# 440094        10440105        52265         Cash
# 440095        10440106        52175         Card
# 440096        10440107        52917         Card
# 440097        10440108        51587         Card
#
# [440098 rows x 3 columns]

# %%
#city dataset

city.head()
city.info()
city.shape

# Statistical data analysis
# Summary statistics
city.describe()

## 20 individuals and 3 variables.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     object
#  2   Users       20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes
#               City Population     Users
# count           20         20        20
# unique          20         20        20
# top     ATLANTA GA   943,999    12,421
# freq             1          1         1

# %%
#city data cleaning and preprocessing

city.isnull().sum()
## There is no missing values
## There is no unimportant variables. No variables to drop.

#drop if there are any duplicate rows
city = city.drop_duplicates(keep='first')
city
## There is no duplicate rows.
## Conclusion : Our city data is clean.
# Out:
#                 City   Population      Users
# 0        NEW YORK NY   8,405,837    302,149
# 1         CHICAGO IL   1,955,130    164,468
# 2     LOS ANGELES CA   1,595,037    144,132
# 3           MIAMI FL   1,339,155     17,675
# 4     SILICON VALLEY   1,177,609     27,247
# 5      ORANGE COUNTY   1,030,185     12,994
# 6       SAN DIEGO CA     959,307     69,995
# 7         PHOENIX AZ     943,999      6,133
# 8          DALLAS TX     942,908     22,157
# 9         ATLANTA GA     814,885     24,701
# 10         DENVER CO     754,233     12,421
# 11         AUSTIN TX     698,371     14,978
# 12        SEATTLE WA     671,238     25,063
# 13         TUCSON AZ     631,442      5,712
# 14  SAN FRANCISCO CA     629,591    213,609
# 15     SACRAMENTO CA     545,776      7,044
# 16     PITTSBURGH PA     542,085      3,643
# 17     WASHINGTON DC     418,859    127,001
# 18      NASHVILLE TN     327,225      9,270
# 19         BOSTON MA     248,968     80,021

# %%
#cab data Univariate Analysis
import seaborn as sns
sns.countplot(x='Company',data=cab) 
## Looking at the results, we can tell that the majority of the cab companies are the Yellow Cab

cab['Company'].value_counts()
## The exact breakdown of the companies are : 
## 274681 Yellow cabs VERSUS 84711 Pink cabs
## Which means that the number of yellow cabs is approximately about 3X pink cabs
# Out:
# Yellow Cab    274681
# Pink Cab       84711
# Name: Company, dtype: int64

# %%
# Box plot to visualize the relationship between KM Travelled and Price Charged
sns.boxplot(x="KM Travelled", y="Price Charged", data = cab)
#Box plot to visualize the relationship between KM Travelled and Cost of Trip
sns.boxplot(x="KM Travelled", y="Cost of Trip", data = cab)
## As many more KM are travelled, the price charged & the cost of the trip are both proportionally higher.

# Assumption: The three variables : 'KM Travelled' 'Price Charged' 'Cost of Trip' are highly correlated. 
#Verify assumption

# Correlation plot // Relation between variables
plt.figure(figsize=(10,20))
c = cab.corr()
sns.heatmap(c, cmap="BrBG", annot=True)
c
## 'KM Travelled' & 'Price Charged', 'KM Travelled' and 'Cost of Trip' are too couples of variables that are highly correlated.

#Correlation between the charge/cost and date of travel
sns.boxplot(data=cab, x='Cost of Trip', y='Date of Travel')

# %%
# Customer dataset
# Transaction dataset

# Statistical data analysis
# Summary statistics
customer.describe()
transaction.describe()

# Combine the two datasets 'transaction' and 'customer', as both of them have 'Customer ID' column 
# Use merge() function
customer_transaction = pd.merge(customer, transaction)
customer_transaction
# Out:
#         Customer ID  Gender  Age  Income (USD/Month)  Transaction ID  \
# 0             29290    Male   28               10813        10000011
# 1             29290    Male   28               10813        10351127
# 2             29290    Male   28               10813        10412921
# 3             27703    Male   27                9237        10000012
# 4             27703    Male   27                9237        10320494
# ...             ...     ...  ...                 ...             ...
# 440093        12490    Male   33               18713        10439799
# 440094        14971    Male   30               15346        10439820
# 440095        41414    Male   38                3960        10439838
# 440096        41677    Male   23               19454        10439840
# 440097        39761  Female   32               10128        10439846
#
#        Payment_Mode
# 0              Card
# 1              Cash
# 2              Card
# 3              Card
# 4              Card
# ...

# %%
#customer_transaction new merged dataset analysis

#univariate analysis

import seaborn as sns
sns.countplot(x='Gender', data = customer_transaction) 

## There is no equal distribution Gender wise : Male customers > Female customers

## The exact breakdown of the companies are : 
customer_transaction['Gender'].value_counts()
## 256611 Male cab users VERSUS 183487 Female cab users
# Out:
# Male      256611
# Female    183487
# Name: Gender, dtype: int64

# %%
#Make an all-in-one dataset 

# Create a new dataset for the analysis
# Merge the two datasets 'customer_transaction' & 'cab'

cab_cust_trans = pd.merge(cab, customer_transaction)
cab_cust_trans

#Now, merge the 4th dataset 'City' to get all in one DATASET on which all the analysis is done

df = pd.merge(cab_cust_trans, city)
df

#The final dataset df contains 359392 rows/individuals and 14 columns/variables
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10000012           42375    Pink Cab     ATLANTA GA
# 2             10000013           42371    Pink Cab     ATLANTA GA
# 3             10000014           42376    Pink Cab     ATLANTA GA
# 4             10000015           42372    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip  Customer ID Gender  Age  \
# 0              30.45         370.95      313.6350        29290   Male   28
# ...

# %%
# Correlation plot
# relation between the different variables of the dataset

plt.figure(figsize=(10,20))
c = df.corr()
sns.heatmap(c, 
cmap='RdBu_r', 
annot=True,
vmin=-1, vmax=1)
c
# Out:
#                     Transaction ID  Date of Travel  KM Travelled  \
# Transaction ID            1.000000        0.993030     -0.001429
# Date of Travel            0.993030        1.000000     -0.001621
# KM Travelled             -0.001429       -0.001621      1.000000
# Price Charged            -0.052902       -0.055559      0.835753
# Cost of Trip             -0.003462       -0.004484      0.981848
# Customer ID              -0.016912       -0.017653      0.000389
# Age                      -0.001267       -0.001346     -0.000369
# Income (USD/Month)       -0.001570       -0.001368     -0.000544
#
#                     Price Charged  Cost of Trip  Customer ID       Age  \
# Transaction ID          -0.052902     -0.003462    -0.016912 -0.001267
# Date of Travel          -0.055559     -0.004484    -0.017653 -0.001346
# KM Travelled             0.835753      0.981848     0.000389 -0.000369
# Price Charged            1.000000      0.859812    -0.177324 -0.003084
# ...

# %%
# analysis based on the charged price
sns.barplot(data=df, x="Company", y="Price Charged")
## The Yellow Cab company charges more than the Pink Cab company

#analysis based on cost of the trip
sns.barplot(data=df, x="Company", y="Cost of Trip")
## Since the Price Charged and Cost of Trip are proportional and highly correlated 
## Then the Yellow Cab company's trips cost more than those of the Pink Cab company

# %%
# Bivariate analysis
# previous analysis confirmation
# based on both price charged and cost of trip
sns.relplot(
    x='Price Charged', 
    y='Cost of Trip', 
    data=df, 
    kind='scatter', 
    col='Company');

## Yellow cab company both charges and costs more than the Pink cab company.

# %%
# Multivariate analysis
sns.catplot(
    x='Company', 
    y='Cost of Trip', 
    data=df, 
    palette='bright',
    kind='point', 
    hue='Payment_Mode');

## The distribution of the payment method between card cash is almost the same for  the Yellow cab firm and the Pink cab firm.

# %%
sns.barplot(data=df, x="Company", y="Age")

# Equal distribution of age among the two cab companies Pink Cab & Yellow Cab.

# %%
# Visualize data one more time
df.info()

# convert xlrd to Python date time type
import pandas as pd


df['Date of Travel'] = pd.to_datetime(df['Date of Travel'], unit='D')

df['Date of Travel']

# check date type conversion
df.info()

# convert Population column type from object to float64.
#df['Population'] = df['Population'].str.replace(',','').astype(np.float64)
#df['Users'] = df['Users'].str.replace(',','').astype(int)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359392 entries, 0 to 359391
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Transaction ID      359392 non-null  int64
#  1   Date of Travel      359392 non-null  datetime64[ns]
#  2   Company             359392 non-null  object
#  3   City                359392 non-null  object
#  4   KM Travelled        359392 non-null  float64
#  5   Price Charged       359392 non-null  float64
#  6   Cost of Trip        359392 non-null  float64
#  7   Customer ID         359392 non-null  int64
#  8   Gender              359392 non-null  object
#  9   Age                 359392 non-null  int64
#  10  Income (USD/Month)  359392 non-null  int64
#  11  Payment_Mode        359392 non-null  object
#  12  Population          359392 non-null  float64
#  13  Users               359392 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(4), object(5)
# ...
